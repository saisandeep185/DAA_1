# %% [markdown]
# # Linear Search

# %%
import time

# Input from user
n = int(input("Enter the number of elements: "))

arr = []
print("Enter the elements:")
for i in range(n):
    arr.append(int(input()))

key = int(input("Enter the element to search: "))

# Start execution time
start_time = time.perf_counter()

# Linear Search
found = False
position = -1

for i in range(n):
    if arr[i] == key:
        found = True
        position = i
        break

# End execution time
end_time = time.perf_counter()

# Calculate execution time
execution_time = (end_time - start_time) * 1_000_000  # Convert to microseconds

# Display result
if found:
    print(f"\nElement {key} found at position {position + 1}")
else:
    print(f"\nElement {key} not found in the array.")

# Display execution time
print(f"\nExecution Time: {execution_time:.2f} microseconds")

# Display time complexity
print("\nTime Complexity:")
print("Best Case    : O(1)")
print("Average Case : O(n)")
print("Worst Case   : O(n)")
# Out:
# Enter the number of elements:  5
# Enter the elements:
#  12
#  30
#  45
#  90
#  65
# Enter the element to search:  65
# Element 65 found at position 5
#
# Execution Time: 313.80 microseconds
#
# Time Complexity:
# Best Case    : O(1)
# Average Case : O(n)
# Worst Case   : O(n)

# %% [markdown]
# # Binary Search

# %%
import time

# Input from user
n = int(input("Enter the number of elements: "))

arr = []
print("Enter the elements:")
for i in range(n):
    arr.append(int(input()))

# Sort the array (Binary Search requires a sorted array)
arr.sort()

print("\nSorted Array:")
print(arr)

key = int(input("\nEnter the element to search: "))

# Start execution time
start_time = time.perf_counter()

# Binary Search
low = 0
high = n - 1
found = False
position = -1

while low <= high:
    mid = (low + high) // 2

    if arr[mid] == key:
        found = True
        position = mid
        break
    elif arr[mid] < key:
        low = mid + 1
    else:
        high = mid - 1

# End execution time
end_time = time.perf_counter()

# Calculate execution time
execution_time = (end_time - start_time) * 1_000_000  # Convert to microseconds

# Display result
if found:
    print(f"\nElement {key} found at position {position + 1}")
else:
    print(f"\nElement {key} not found in the array.")

# Display execution time
print(f"\nExecution Time: {execution_time:.2f} microseconds")

# Display time complexity
print("\nTime Complexity:")
print("Best Case    : O(1)")
print("Average Case : O(log n)")
print("Worst Case   : O(log n)")
# Out:
# Enter the number of elements:  5
# Enter the elements:
#  15
#  -6
#  20
#  6
#  80
# Sorted Array:
# [-6, 6, 15, 20, 80]
# Enter the element to search:  20
# Element 20 found at position 4
#
# Execution Time: 483.90 microseconds
#
# Time Complexity:
# Best Case    : O(1)
# Average Case : O(log n)
# Worst Case   : O(log n)
